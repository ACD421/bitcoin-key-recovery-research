# %%
import hashlib
from Crypto.Hash import RIPEMD160
import ecdsa
import binascii
import base58

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")

def hamming_distance(b1, b2):
    return sum(bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1)))

def bytes_matching(b1, b2):
    return sum(1 for i in range(len(b1)) if b1[i] == b2[i])

def gen_address(seed):
    priv_key = hashlib.sha256(seed.encode()).hexdigest()
    key = ecdsa.SigningKey.from_string(binascii.unhexlify(priv_key), curve=ecdsa.SECP256k1)
    pub_key = key.verifying_key.to_string("uncompressed")
    sha256_hash = hashlib.sha256(pub_key).digest()
    hash160 = RIPEMD160.new(sha256_hash).digest()
    addr_bytes = b'\x00' + hash160
    checksum = hashlib.sha256(hashlib.sha256(addr_bytes).digest()).digest()[:4]
    address = base58.b58encode(addr_bytes + checksum).decode()
    return address, hash160

seed = "bitcoin2009-26094"
addr, hash160 = gen_address(seed)
ham = hamming_distance(hash160, TARGET_HASH160)
bytes_match = bytes_matching(hash160, TARGET_HASH160)
bits_match = 160 - ham

print(f"Seed: {seed}")
print(f"Address: {addr}")
print(f"Hash160: {hash160.hex()}")
print(f"Hamming: {ham}")
print(f"Bits: {bits_match}/160 ({bits_match/160:.2%})")
print(f"Bytes: {bytes_match}/20 ({bytes_match/20:.2%})")
# Out:
# Seed: bitcoin2009-26094
# Address: 1LkELLo1HWFssMwNxvY6aDX3QxvFcCNyV1
# Hash160: d897680e59e95749d96de29522431bb4329e6c95
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)

# %%
import hashlib
from Crypto.Hash import RIPEMD160
import ecdsa
import binascii
import base58

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")

def hamming_distance(b1, b2):
    return sum(bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1)))

def bytes_matching(b1, b2):
    return sum(1 for i in range(len(b1)) if b1[i] == b2[i])

def gen_address(seed, method='raw'):
    if method == 'raw':
        priv_key = hashlib.sha256(seed.encode()).hexdigest()
    else:  # md5
        priv_key = hashlib.md5(seed.encode()).hexdigest() + "0" * 32
    key = ecdsa.SigningKey.from_string(binascii.unhexlify(priv_key), curve=ecdsa.SECP256k1)
    pub_key = key.verifying_key.to_string("uncompressed")
    sha256_hash = hashlib.sha256(pub_key).digest()
    hash160 = RIPEMD160.new(sha256_hash).digest()
    addr_bytes = b'\x00' + hash160
    checksum = hashlib.sha256(hashlib.sha256(addr_bytes).digest()).digest()[:4]
    address = base58.b58encode(addr_bytes + checksum).decode()
    return address, hash160

seed = "bitcoin2009-26094"
for method in ['raw', 'md5']:
    addr, hash160 = gen_address(seed, method)
    ham = hamming_distance(hash160, TARGET_HASH160)
    bytes_match = bytes_matching(hash160, TARGET_HASH160)
    bits_match = 160 - ham
    print(f"\nMethod: {method.upper()}")
    print(f"Seed: {seed}")
    print(f"Address: {addr}")
    print(f"Hash160: {hash160.hex()}")
    print(f"Hamming: {ham}")
    print(f"Bits: {bits_match}/160 ({bits_match/160:.2%})")
    print(f"Bytes: {bytes_match}/20 ({bytes_match/20:.2%})")
# Out:
# Method: RAW
# Seed: bitcoin2009-26094
# Address: 1LkELLo1HWFssMwNxvY6aDX3QxvFcCNyV1
# Hash160: d897680e59e95749d96de29522431bb4329e6c95
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)
#
# Method: MD5
# Seed: bitcoin2009-26094
# Address: 13Jf4AWFto6FGj2QsTusHKKJWveS94yMtX
# Hash160: 194716d97d64f15e133532052c764fbf6953b981
# Hamming: 78
# Bits: 82/160 (51.25%)
# Bytes: 0/20 (0.00%)

# %%
import hashlib
from Crypto.Hash import RIPEMD160
import ecdsa
import binascii
import base58

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")

def hamming_distance(b1, b2):
    return sum(bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1)))

def bytes_matching(b1, b2):
    return sum(1 for i in range(len(b1)) if b1[i] == b2[i])

def gen_address(seed, method='raw'):
    if method == 'raw':
        priv_key = hashlib.sha256(seed.encode()).hexdigest()
    else:  # md5
        priv_key = hashlib.md5(seed.encode()).hexdigest() + "0" * 32
    key = ecdsa.SigningKey.from_string(binascii.unhexlify(priv_key), curve=ecdsa.SECP256k1)
    pub_key = key.verifying_key.to_string("uncompressed")
    sha256_hash = hashlib.sha256(pub_key).digest()
    hash160 = RIPEMD160.new(sha256_hash).digest()
    addr_bytes = b'\x00' + hash160
    checksum = hashlib.sha256(hashlib.sha256(addr_bytes).digest()).digest()[:4]
    address = base58.b58encode(addr_bytes + checksum).decode()
    return address, hash160

seed = "bitcoin2009-26094"
for method in ['raw', 'md5']:
    addr, hash160 = gen_address(seed, method)
    ham = hamming_distance(hash160, TARGET_HASH160)
    bytes_match = bytes_matching(hash160, TARGET_HASH160)
    bits_match = 160 - ham
    print(f"\nMethod: {method.upper()}")
    print(f"Seed: {seed}")
    print(f"Address: {addr}")
    print(f"Hash160: {hash160.hex()}")
    print(f"Hamming: {ham}")
    print(f"Bits: {bits_match}/160 ({bits_match/160:.2%})")
    print(f"Bytes: {bytes_match}/20 ({bytes_match/20:.2%})")
# Out:
# Method: RAW
# Seed: bitcoin2009-26094
# Address: 1LkELLo1HWFssMwNxvY6aDX3QxvFcCNyV1
# Hash160: d897680e59e95749d96de29522431bb4329e6c95
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)
#
# Method: MD5
# Seed: bitcoin2009-26094
# Address: 13Jf4AWFto6FGj2QsTusHKKJWveS94yMtX
# Hash160: 194716d97d64f15e133532052c764fbf6953b981
# Hamming: 78
# Bits: 82/160 (51.25%)
# Bytes: 0/20 (0.00%)

# %%
import hashlib
from Crypto.Hash import RIPEMD160
import ecdsa
import binascii
import base58

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")

def hamming_distance(b1, b2):
    return sum(bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1)))

def bytes_matching(b1, b2):
    return sum(1 for i in range(len(b1)) if b1[i] == b2[i])

def gen_address(seed, method='raw'):
    if method == 'raw':
        priv_key = hashlib.sha256(seed.encode()).hexdigest()
    else:
        priv_key = hashlib.md5(seed.encode()).hexdigest() + "0" * 32
    key = ecdsa.SigningKey.from_string(binascii.unhexlify(priv_key), curve=ecdsa.SECP256k1)
    pub_key = key.verifying_key.to_string("uncompressed")
    sha256_hash = hashlib.sha256(pub_key).digest()
    hash160 = RIPEMD160.new(sha256_hash).digest()
    addr_bytes = b'\x00' + hash160
    checksum = hashlib.sha256(hashlib.sha256(addr_bytes).digest()).digest()[:4]
    address = base58.b58encode(addr_bytes + checksum).decode()
    return address, hash160, priv_key

seed = "bitcoin2009-26094"
for method in ['raw', 'md5']:
    addr, hash160, priv_key = gen_address(seed, method)
    ham = hamming_distance(hash160, TARGET_HASH160)
    bytes_match = bytes_matching(hash160, TARGET_HASH160)
    bits_match = 160 - ham
    print(f"\nMethod: {method.upper()}")
    print(f"Seed: {seed}")
    print(f"Priv Key: {priv_key}")
    print(f"Address: {addr}")
    print(f"Hash160: {hash160.hex()}")
    print(f"Hamming: {ham}")
    print(f"Bits: {bits_match}/160 ({bits_match/160:.2%})")
    print(f"Bytes: {bytes_match}/20 ({bytes_match/20:.2%})")
# Out:
# Method: RAW
# Seed: bitcoin2009-26094
# Priv Key: 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
# Address: 1LkELLo1HWFssMwNxvY6aDX3QxvFcCNyV1
# Hash160: d897680e59e95749d96de29522431bb4329e6c95
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)
#
# Method: MD5
# Seed: bitcoin2009-26094
# Priv Key: 6d0f799040bfb8f8318f5124027c83fe00000000000000000000000000000000
# Address: 13Jf4AWFto6FGj2QsTusHKKJWveS94yMtX
# Hash160: 194716d97d64f15e133532052c764fbf6953b981
# Hamming: 78
# Bits: 82/160 (51.25%)
# Bytes: 0/20 (0.00%)

# %%
import hashlib
from Crypto.Hash import RIPEMD160
import ecdsa
import binascii
import base58

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")

def hamming_distance(b1, b2):
    return sum(bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1)))

def bytes_matching(b1, b2):
    return sum(1 for i in range(len(b1)) if b1[i] == b2[i])

def gen_address_from_priv(priv_key_hex):
    key = ecdsa.SigningKey.from_string(binascii.unhexlify(priv_key_hex), curve=ecdsa.SECP256k1)
    pub_key = key.verifying_key.to_string("uncompressed")
    sha256_hash = hashlib.sha256(pub_key).digest()
    hash160 = RIPEMD160.new(sha256_hash).digest()
    addr_bytes = b'\x00' + hash160
    checksum = hashlib.sha256(hashlib.sha256(addr_bytes).digest()).digest()[:4]
    address = base58.b58encode(addr_bytes + checksum).decode()
    return address, hash160

# Your RAW priv key
your_priv = "23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097"
addr, hash160 = gen_address_from_priv(your_priv)
ham = hamming_distance(hash160, TARGET_HASH160)
bytes_match = bytes_matching(hash160, TARGET_HASH160)
bits_match = 160 - ham
print("\nYour RAW Priv Key:")
print(f"Priv Key: {your_priv}")
print(f"Address: {addr}")
print(f"Hash160: {hash160.hex()}")
print(f"Hamming: {ham}")
print(f"Bits: {bits_match}/160 ({bits_match/160:.2%})")
print(f"Bytes: {bytes_match}/20 ({bytes_match/20:.2%})")

# My RAW calc
seed = "bitcoin2009-26094"
my_priv = hashlib.sha256(seed.encode()).hexdigest()
addr, hash160 = gen_address_from_priv(my_priv)
ham = hamming_distance(hash160, TARGET_HASH160)
bytes_match = bytes_matching(hash160, TARGET_HASH160)
bits_match = 160 - ham
print("\nMy RAW Calc:")
print(f"Seed: {seed}")
print(f"Priv Key: {my_priv}")
print(f"Address: {addr}")
print(f"Hash160: {hash160.hex()}")
print(f"Hamming: {ham}")
print(f"Bits: {bits_match}/160 ({bits_match/160:.2%})")
print(f"Bytes: {bytes_match}/20 ({bytes_match/20:.2%})")
# Out:
# Your RAW Priv Key:
# Priv Key: 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
# Address: 1LkELLo1HWFssMwNxvY6aDX3QxvFcCNyV1
# Hash160: d897680e59e95749d96de29522431bb4329e6c95
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)
#
# My RAW Calc:
# Seed: bitcoin2009-26094
# Priv Key: 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
# Address: 1LkELLo1HWFssMwNxvY6aDX3QxvFcCNyV1
# Hash160: d897680e59e95749d96de29522431bb4329e6c95
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)

# %%
import hashlib
from Crypto.Hash import RIPEMD160
import ecdsa
import binascii
import base58

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")

def hamming_distance(b1, b2):
    return sum(bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1)))

def bytes_matching(b1, b2):
    return sum(1 for i in range(len(b1)) if b1[i] == b2[i])

def gen_address_from_priv(priv_key_hex):
    key = ecdsa.SigningKey.from_string(binascii.unhexlify(priv_key_hex), curve=ecdsa.SECP256k1)
    pub_key = key.verifying_key.to_string("uncompressed")
    sha256_hash = hashlib.sha256(pub_key).digest()
    hash160 = RIPEMD160.new(sha256_hash).digest()
    addr_bytes = b'\x00' + hash160
    checksum = hashlib.sha256(hashlib.sha256(addr_bytes).digest()).digest()[:4]
    address = base58.b58encode(addr_bytes + checksum).decode()
    return address, hash160

priv = "23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097"
addr, hash160 = gen_address_from_priv(priv)
ham = hamming_distance(hash160, TARGET_HASH160)
bytes_match = bytes_matching(hash160, TARGET_HASH160)
print(f"Priv: {priv}")
print(f"Address: {addr}")
print(f"Hash160: {hash160.hex()}")
print(f"Hamming: {ham}")
print(f"Bits: {160 - ham}/160 ({(160 - ham)/160:.2%})")
print(f"Bytes: {bytes_match}/20 ({bytes_match/20:.2%})")
# Out:
# Priv: 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
# Address: 1LkELLo1HWFssMwNxvY6aDX3QxvFcCNyV1
# Hash160: d897680e59e95749d96de29522431bb4329e6c95
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)

# %%
import hashlib
from Crypto.Hash import RIPEMD160
import ecdsa
import binascii
import base58

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")

def hamming_distance(b1, b2):
    return sum(bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1)))

def bytes_matching(b1, b2):
    return sum(1 for i in range(len(b1)) if b1[i] == b2[i])

def gen_address_from_priv(priv_key_hex):
    key = ecdsa.SigningKey.from_string(binascii.unhexlify(priv_key_hex), curve=ecdsa.SECP256k1)
    pub_key = key.verifying_key.to_string("uncompressed")
    sha256_hash = hashlib.sha256(pub_key).digest()
    hash160 = RIPEMD160.new(sha256_hash).digest()
    addr_bytes = b'\x00' + hash160
    checksum = hashlib.sha256(hashlib.sha256(addr_bytes).digest()).digest()[:4]
    address = base58.b58encode(addr_bytes + checksum).decode()
    return address, hash160

priv = "23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097"
addr, hash160 = gen_address_from_priv(priv)
ham = hamming_distance(hash160, TARGET_HASH160)
bytes_match = bytes_matching(hash160, TARGET_HASH160)
bits_match = 160 - ham

print(f"Priv: {priv}")
print(f"Address: {addr}")
print(f"Hash160: {hash160.hex()}")
print(f"Hamming: {ham}")
print(f"Bits: {bits_match}/160 ({bits_match/160:.2%})")
print(f"Bytes: {bytes_match}/20 ({bytes_match/20:.2%})")

# Double-check byte-by-byte
print("\nByte-by-byte XOR:")
for i in range(20):
    target_byte = TARGET_HASH160[i]
    test_byte = hash160[i]
    diff = bin(target_byte ^ test_byte).count('1')
    print(f"Byte {i}: {hex(target_byte)} ^ {hex(test_byte)} = {hex(target_byte ^ test_byte)} ({diff} bits)")
# Out:
# Priv: 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
# Address: 1LkELLo1HWFssMwNxvY6aDX3QxvFcCNyV1
# Hash160: d897680e59e95749d96de29522431bb4329e6c95
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)
#
# Byte-by-byte XOR:
# Byte 0: 0xa0 ^ 0xd8 = 0x78 (4 bits)
# Byte 1: 0xb0 ^ 0x97 = 0x27 (4 bits)
# Byte 2: 0xd6 ^ 0x68 = 0xbe (6 bits)
# Byte 3: 0xe ^ 0xe = 0x0 (0 bits)
# Byte 4: 0x59 ^ 0x59 = 0x0 (0 bits)
# Byte 5: 0x91 ^ 0xe9 = 0x78 (4 bits)
# Byte 6: 0x57 ^ 0x57 = 0x0 (0 bits)
# Byte 7: 0x8e ^ 0x49 = 0xc7 (5 bits)
# Byte 8: 0xd3 ^ 0xd9 = 0xa (2 bits)
# Byte 9: 0x7c ^ 0x6d = 0x11 (2 bits)
# Byte 10: 0xbd ^ 0xe2 = 0x5f (6 bits)
# Byte 11: 0xa2 ^ 0x95 = 0x37 (5 bits)
# Byte 12: 0xb1 ^ 0x22 = 0x93 (4 bits)
# Byte 13: 0x7d ^ 0x43 = 0x3e (5 bits)
# Byte 14: 0x8b ^ 0x1b = 0x90 (2 bits)
# Byte 15: 0x2c ^ 0xb4 = 0x98 (3 bits)
# Byte 16: 0xe2 ^ 0x32 = 0xd0 (3 bits)
# Byte 17: 0x3a ^ 0x9e = 0xa4 (3 bits)
# Byte 18: 0xb2 ^ 0x6c = 0xde (6 bits)
# ...

# %%
TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")
TEST_HASH160 = binascii.unhexlify("d897680e59e95749d96de29522431bb4329e6c95")

def hamming_distance(b1, b2):
    return sum(bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1)))

ham = hamming_distance(TARGET_HASH160, TEST_HASH160)
print(f"Hamming: {ham}")
print(f"Bits: {160 - ham}/160 ({(160 - ham)/160:.2%})")
# Out:
# Hamming: 64
# Bits: 96/160 (60.00%)

# %%
import binascii

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")
TEST_HASH160 = binascii.unhexlify("d897680e59e95749d96de29522431bb4329e6c95")

def hamming_distance(b1, b2):
    return sum(bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1)))

def bytes_matching(b1, b2):
    return sum(1 for i in range(len(b1)) if b1[i] == b2[i])

ham = hamming_distance(TARGET_HASH160, TEST_HASH160)
bytes_match = bytes_matching(TARGET_HASH160, TEST_HASH160)
print(f"Hamming: {ham}")
print(f"Bits: {160 - ham}/160 ({(160 - ham)/160:.2%})")
print(f"Bytes: {bytes_match}/20 ({bytes_match/20:.2%})")
# Out:
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)

# %%
import binascii

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")
TEST_HASH160 = binascii.unhexlify("d897680e59e95749d96de29522431bb4329e6c95")

def hamming_distance(b1, b2):
    return sum(bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1)))

def bytes_matching(b1, b2):
    return sum(1 for i in range(len(b1)) if b1[i] == b2[i])

ham = hamming_distance(TARGET_HASH160, TEST_HASH160)
bytes_match = bytes_matching(TARGET_HASH160, TEST_HASH160)
print(f"Target: {TARGET_HASH160.hex()}")
print(f"Test: {TEST_HASH160.hex()}")
print(f"Hamming: {ham}")
print(f"Bits: {160 - ham}/160 ({(160 - ham)/160:.2%})")
print(f"Bytes: {bytes_match}/20 ({bytes_match/20:.2%})")
# Out:
# Target: a0b0d60e5991578ed37cbda2b17d8b2ce23ab295
# Test: d897680e59e95749d96de29522431bb4329e6c95
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)

# %%
import hashlib
from Crypto.Hash import RIPEMD160
import ecdsa
import binascii
import base58

def gen_address_from_priv(priv_key_hex):
    key = ecdsa.SigningKey.from_string(binascii.unhexlify(priv_key_hex), curve=ecdsa.SECP256k1)
    pub_key = key.verifying_key.to_string("uncompressed")
    sha256_hash = hashlib.sha256(pub_key).digest()
    hash160 = RIPEMD160.new(sha256_hash).digest()
    addr_bytes = b'\x00' + hash160
    checksum = hashlib.sha256(hashlib.sha256(addr_bytes).digest()).digest()[:4]
    address = base58.b58encode(addr_bytes + checksum).decode()
    return address, hash160

priv = "23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097"
addr, hash160 = gen_address_from_priv(priv)
print(f"Address: {addr}")
print(f"Hash160: {hash160.hex()}")
# Out:
# Address: 1LkELLo1HWFssMwNxvY6aDX3QxvFcCNyV1
# Hash160: d897680e59e95749d96de29522431bb4329e6c95

# %%
import binascii

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")
TEST_HASH160 = binascii.unhexlify("d897680e59e95749d96de29522431bb4329e6c95")

def hamming_distance(b1, b2):
    return sum(bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1)))

def bytes_matching(b1, b2):
    return sum(1 for i in range(len(b1)) if b1[i] == b2[i])

ham = hamming_distance(TARGET_HASH160, TEST_HASH160)
bytes_match = bytes_matching(TARGET_HASH160, TEST_HASH160)
print(f"Target: {TARGET_HASH160.hex()}")
print(f"Test: {TEST_HASH160.hex()}")
print(f"Hamming: {ham}")
print(f"Bits: {160 - ham}/160 ({(160 - ham)/160:.2%})")
print(f"Bytes: {bytes_match}/20 ({bytes_match/20:.2%})")
# Out:
# Target: a0b0d60e5991578ed37cbda2b17d8b2ce23ab295
# Test: d897680e59e95749d96de29522431bb4329e6c95
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)

# %%
import binascii

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")
TEST_HASH160 = binascii.unhexlify("d897680e59e95749d96de29522431bb4329e6c95")

def hamming_distance(b1, b2):
    return sum(bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1)))

def bytes_matching(b1, b2):
    return sum(1 for i in range(len(b1)) if b1[i] == b2[i])

ham = hamming_distance(TARGET_HASH160, TEST_HASH160)
bytes_match = bytes_matching(TARGET_HASH160, TEST_HASH160)
print(f"Hamming: {ham}")
print(f"Bits: {160 - ham}/160 ({(160 - ham)/160:.2%})")
print(f"Bytes: {bytes_match}/20 ({bytes_match/20:.2%})")
# Out:
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)

# %%
seed_part1 = "bitcoin2009"
seed_part2 = "-26094"
priv = hashlib.sha256((seed_part1 + seed_part2).encode()).hexdigest()
hash160 = gen_address_from_priv(priv)
ham = hamming_distance(hash160, TARGET_HASH160)
print(f"Concat Hash160: {hash160.hex()}")
print(f"Hamming: {ham}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-22fc7ed31007> in <cell line: 0>()
#       3 priv = hashlib.sha256((seed_part1 + seed_part2).encode()).hexdigest()
#       4 hash160 = gen_address_from_priv(priv)
# ----> 5 ham = hamming_distance(hash160, TARGET_HASH160)
#       6 print(f"Concat Hash160: {hash160.hex()}")
#       7 print(f"Hamming: {ham}")
#
# <ipython-input-21-f0ea9167dcd6> in hamming_distance(b1, b2)
#       5
#       6 def hamming_distance(b1, b2):
# ----> 7     return sum(bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1)))
#       8
#       9 def bytes_matching(b1, b2):
#
# <ipython-input-21-f0ea9167dcd6> in <genexpr>(.0)
#       5
#       6 def hamming_distance(b1, b2):
# ----> 7     return sum(bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1)))
#       8
#       9 def bytes_matching(b1, b2):
#
# ...

# %%
import binascii

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")
TEST_HASH160 = binascii.unhexlify("d897680e59e95749d96de29522431bb4329e6c95")

def hamming_distance(b1, b2):
    return sum(bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1)))

def bytes_matching(b1, b2):
    return sum(1 for i in range(len(b1)) if b1[i] == b2[i])

ham = hamming_distance(TARGET_HASH160, TEST_HASH160)
bytes_match = bytes_matching(TARGET_HASH160, TEST_HASH160)
print(f"Hamming: {ham}")
print(f"Bits: {160 - ham}/160 ({(160 - ham)/160:.2%})")
print(f"Bytes: {bytes_match}/20 ({bytes_match/20:.2%})")
# Out:
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)

# %%
import hashlib
from Crypto.Hash import RIPEMD160
import ecdsa
import binascii
import base58

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")

def hamming_distance(b1, b2):
    return sum(bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1)))

def bytes_matching(b1, b2):
    return sum(1 for i in range(len(b1)) if b1[i] == b2[i])

def gen_address_from_priv(priv_key_hex):
    key = ecdsa.SigningKey.from_string(binascii.unhexlify(priv_key_hex), curve=ecdsa.SECP256k1)
    pub_key = key.verifying_key.to_string("uncompressed")
    sha256_hash = hashlib.sha256(pub_key).digest()
    hash160 = RIPEMD160.new(sha256_hash).digest()
    addr_bytes = b'\x00' + hash160
    checksum = hashlib.sha256(hashlib.sha256(addr_bytes).digest()).digest()[:4]
    address = base58.b58encode(addr_bytes + checksum).decode()
    return address, hash160

# Double SHA-256
seed = "bitcoin2009-26094"
priv_double = hashlib.sha256(hashlib.sha256(seed.encode()).digest()).hexdigest()
addr_double, hash160_double = gen_address_from_priv(priv_double)
ham_double = hamming_distance(hash160_double, TARGET_HASH160)
bytes_double = bytes_matching(hash160_double, TARGET_HASH160)
print("Double SHA-256:")
print(f"Priv: {priv_double}")
print(f"Address: {addr_double}")
print(f"Hash160: {hash160_double.hex()}")
print(f"Hamming: {ham_double}")
print(f"Bits: {160 - ham_double}/160 ({(160 - ham_double)/160:.2%})")
print(f"Bytes: {bytes_double}/20 ({bytes_double/20:.2%})")

# Concatenation
seed_part1 = "bitcoin2009"
seed_part2 = "-26094"
priv_concat = hashlib.sha256((seed_part1 + seed_part2).encode()).hexdigest()
addr_concat, hash160_concat = gen_address_from_priv(priv_concat)
ham_concat = hamming_distance(hash160_concat, TARGET_HASH160)
bytes_concat = bytes_matching(hash160_concat, TARGET_HASH160)
print("\nConcatenation:")
print(f"Priv: {priv_concat}")
print(f"Address: {addr_concat}")
print(f"Hash160: {hash160_concat.hex()}")
print(f"Hamming: {ham_concat}")
print(f"Bits: {160 - ham_concat}/160 ({(160 - ham_concat)/160:.2%})")
print(f"Bytes: {bytes_concat}/20 ({bytes_concat/20:.2%})")

# Your Priv Key
priv_yours = "23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097"
addr_yours, hash160_yours = gen_address_from_priv(priv_yours)
ham_yours = hamming_distance(hash160_yours, TARGET_HASH160)
bytes_yours = bytes_matching(hash160_yours, TARGET_HASH160)
print("\nYour Priv Key:")
print(f"Priv: {priv_yours}")
print(f"Address: {addr_yours}")
print(f"Hash160: {hash160_yours.hex()}")
print(f"Hamming: {ham_yours}")
print(f"Bits: {160 - ham_yours}/160 ({(160 - ham_yours)/160:.2%})")
print(f"Bytes: {bytes_yours}/20 ({bytes_yours/20:.2%})")
# Out:
# Double SHA-256:
# Priv: 35ef412241fca23ecbabd2cda82e241aef553374dc1a5c3473c46efbf182c8f0
# Address: 13RkYUW8FTHmvxT4BPmMh5ukifPWra5EVN
# Hash160: 1a9e950d18ffd0f04c5c614c5bb27b2be050b479
# Hamming: 79
# Bits: 81/160 (50.62%)
# Bytes: 0/20 (0.00%)
#
# Concatenation:
# Priv: 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
# Address: 1LkELLo1HWFssMwNxvY6aDX3QxvFcCNyV1
# Hash160: d897680e59e95749d96de29522431bb4329e6c95
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)
#
# Your Priv Key:
# Priv: 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
# Address: 1LkELLo1HWFssMwNxvY6aDX3QxvFcCNyV1
# Hash160: d897680e59e95749d96de29522431bb4329e6c95
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)

# %%
import hashlib
from Crypto.Hash import RIPEMD160
import ecdsa
import binascii
import base58

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")

def hamming_distance(b1, b2):
    return sum(bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1)))

def bytes_matching(b1, b2):
    return sum(1 for i in range(len(b1)) if b1[i] == b2[i])

def gen_address_from_priv(priv_key_hex):
    key = ecdsa.SigningKey.from_string(binascii.unhexlify(priv_key_hex), curve=ecdsa.SECP256k1)
    pub_key = key.verifying_key.to_string("uncompressed")
    sha256_hash = hashlib.sha256(pub_key).digest()
    hash160 = RIPEMD160.new(sha256_hash).digest()
    addr_bytes = b'\x00' + hash160
    checksum = hashlib.sha256(hashlib.sha256(addr_bytes).digest()).digest()[:4]
    address = base58.b58encode(addr_bytes + checksum).decode()
    return address, hash160

# Double SHA-256
seed = "bitcoin2009-26094"
priv_double = hashlib.sha256(hashlib.sha256(seed.encode()).digest()).hexdigest()
addr_double, hash160_double = gen_address_from_priv(priv_double)
ham_double = hamming_distance(hash160_double, TARGET_HASH160)
bytes_double = bytes_matching(hash160_double, TARGET_HASH160)
print("Double SHA-256:")
print(f"Priv: {priv_double}")
print(f"Address: {addr_double}")
print(f"Hash160: {hash160_double.hex()}")
print(f"Hamming: {ham_double}")
print(f"Bits: {160 - ham_double}/160 ({(160 - ham_double)/160:.2%})")
print(f"Bytes: {bytes_double}/20 ({bytes_double/20:.2%})")

# Concatenation
seed_part1 = "bitcoin2009"
seed_part2 = "-26094"
priv_concat = hashlib.sha256((seed_part1 + seed_part2).encode()).hexdigest()
addr_concat, hash160_concat = gen_address_from_priv(priv_concat)
ham_concat = hamming_distance(hash160_concat, TARGET_HASH160)
bytes_concat = bytes_matching(hash160_concat, TARGET_HASH160)
print("\nConcatenation:")
print(f"Priv: {priv_concat}")
print(f"Address: {addr_concat}")
print(f"Hash160: {hash160_concat.hex()}")
print(f"Hamming: {ham_concat}")
print(f"Bits: {160 - ham_concat}/160 ({(160 - ham_concat)/160:.2%})")
print(f"Bytes: {bytes_concat}/20 ({bytes_concat/20:.2%})")

# Your Priv Key
priv_yours = "23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097"
addr_yours, hash160_yours = gen_address_from_priv(priv_yours)
ham_yours = hamming_distance(hash160_yours, TARGET_HASH160)
bytes_yours = bytes_matching(hash160_yours, TARGET_HASH160)
print("\nYour Priv Key:")
print(f"Priv: {priv_yours}")
print(f"Address: {addr_yours}")
print(f"Hash160: {hash160_yours.hex()}")
print(f"Hamming: {ham_yours}")
print(f"Bits: {160 - ham_yours}/160 ({(160 - ham_yours)/160:.2%})")
print(f"Bytes: {bytes_yours}/20 ({bytes_yours/20:.2%})")
# Out:
# Double SHA-256:
# Priv: 35ef412241fca23ecbabd2cda82e241aef553374dc1a5c3473c46efbf182c8f0
# Address: 13RkYUW8FTHmvxT4BPmMh5ukifPWra5EVN
# Hash160: 1a9e950d18ffd0f04c5c614c5bb27b2be050b479
# Hamming: 79
# Bits: 81/160 (50.62%)
# Bytes: 0/20 (0.00%)
#
# Concatenation:
# Priv: 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
# Address: 1LkELLo1HWFssMwNxvY6aDX3QxvFcCNyV1
# Hash160: d897680e59e95749d96de29522431bb4329e6c95
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)
#
# Your Priv Key:
# Priv: 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
# Address: 1LkELLo1HWFssMwNxvY6aDX3QxvFcCNyV1
# Hash160: d897680e59e95749d96de29522431bb4329e6c95
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)

# %%
import hashlib
from Crypto.Hash import RIPEMD160
import ecdsa
import binascii
import base58

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")

def hamming_distance(b1, b2):
    return sum(bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1)))

def bytes_matching(b1, b2):
    return sum(1 for i in range(len(b1)) if b1[i] == b2[i])

def gen_address_from_priv(priv_key_hex):
    key = ecdsa.SigningKey.from_string(binascii.unhexlify(priv_key_hex), curve=ecdsa.SECP256k1)
    pub_key = key.verifying_key.to_string("uncompressed")
    sha256_hash = hashlib.sha256(pub_key).digest()
    hash160 = RIPEMD160.new(sha256_hash).digest()
    addr_bytes = b'\x00' + hash160
    checksum = hashlib.sha256(hashlib.sha256(addr_bytes).digest()).digest()[:4]
    address = base58.b58encode(addr_bytes + checksum).decode()
    return address, hash160

# Double SHA-256
seed = "bitcoin2009-26094"
priv_double = hashlib.sha256(hashlib.sha256(seed.encode()).digest()).hexdigest()
addr_double, hash160_double = gen_address_from_priv(priv_double)
ham_double = hamming_distance(hash160_double, TARGET_HASH160)
bytes_double = bytes_matching(hash160_double, TARGET_HASH160)
print("Double SHA-256:")
print(f"Priv: {priv_double}")
print(f"Address: {addr_double}")
print(f"Hash160: {hash160_double.hex()}")
print(f"Hamming: {ham_double}")
print(f"Bits: {160 - ham_double}/160 ({(160 - ham_double)/160:.2%})")
print(f"Bytes: {bytes_double}/20 ({bytes_double/20:.2%})")

# Concatenation
seed_part1 = "bitcoin2009"
seed_part2 = "-26094"
priv_concat = hashlib.sha256((seed_part1 + seed_part2).encode()).hexdigest()
addr_concat, hash160_concat = gen_address_from_priv(priv_concat)
ham_concat = hamming_distance(hash160_concat, TARGET_HASH160)
bytes_concat = bytes_matching(hash160_concat, TARGET_HASH160)
print("\nConcatenation:")
print(f"Priv: {priv_concat}")
print(f"Address: {addr_concat}")
print(f"Hash160: {hash160_concat.hex()}")
print(f"Hamming: {ham_concat}")
print(f"Bits: {160 - ham_concat}/160 ({(160 - ham_concat)/160:.2%})")
print(f"Bytes: {bytes_concat}/20 ({bytes_concat/20:.2%})")

# Your Priv Key
priv_yours = "23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097"
addr_yours, hash160_yours = gen_address_from_priv(priv_yours)
ham_yours = hamming_distance(hash160_yours, TARGET_HASH160)
bytes_yours = bytes_matching(hash160_yours, TARGET_HASH160)
print("\nYour Priv Key:")
print(f"Priv: {priv_yours}")
print(f"Address: {addr_yours}")
print(f"Hash160: {hash160_yours.hex()}")
print(f"Hamming: {ham_yours}")
print(f"Bits: {160 - ham_yours}/160 ({(160 - ham_yours)/160:.2%})")
print(f"Bytes: {bytes_yours}/20 ({bytes_yours/20:.2%})")
# Out:
# Double SHA-256:
# Priv: 35ef412241fca23ecbabd2cda82e241aef553374dc1a5c3473c46efbf182c8f0
# Address: 13RkYUW8FTHmvxT4BPmMh5ukifPWra5EVN
# Hash160: 1a9e950d18ffd0f04c5c614c5bb27b2be050b479
# Hamming: 79
# Bits: 81/160 (50.62%)
# Bytes: 0/20 (0.00%)
#
# Concatenation:
# Priv: 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
# Address: 1LkELLo1HWFssMwNxvY6aDX3QxvFcCNyV1
# Hash160: d897680e59e95749d96de29522431bb4329e6c95
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)
#
# Your Priv Key:
# Priv: 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
# Address: 1LkELLo1HWFssMwNxvY6aDX3QxvFcCNyV1
# Hash160: d897680e59e95749d96de29522431bb4329e6c95
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)

# %%
Double SHA-256:
Priv: 35ef412241fca23ecbabd2cda82e241aef553374dc1a5c3473c46efbf182c8f0
Address: 13RkYUW8FTHmvxT4BPmMh5ukifPWra5EVN
Hash160: 1a9e950d18ffd0f04c5c614c5bb27b2be050b479
Hamming: 79
Bits: 81/160 (50.62%)
Bytes: 0/20 (0.00%)

Concatenation:
Priv: e3feda4138d83f60b66f2c1ebfa5f70a8f684ea8eabf0ebfa7aeadbb2e69eabf
Address: 1Lufud2vBLK6RPHK2YqNZdJ1oW7kT8fLuF
Hash160: d897680e59e95749d96de29522431bb4329e6c95
Hamming: 77
Bits: 83/160 (51.88%)
Bytes: 4/20 (20.00%)

Your Priv Key:
Priv: 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
Address: 1LkELLo1HWFssMwNxvY6aDX3QxvFcCNyV1
Hash160: d897680e59e95749d96de29522431bb4329e6c95
Hamming: 77
Bits: 83/160 (51.88%)
Bytes: 4/20 (20.00%)
# Out:
#   File "<ipython-input-27-325410c74daa>", line 2
#     Priv: 35ef412241fca23ecbabd2cda82e241aef553374dc1a5c3473c46efbf182c8f0
#            ^
# SyntaxError: invalid decimal literal

# %%
import hashlib
from Crypto.Hash import RIPEMD160
import ecdsa
import binascii
import base58

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")

def hamming_distance(b1, b2):
    return sum(bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1)))

def bytes_matching(b1, b2):
    return sum(1 for i in range(len(b1)) if b1[i] == b2[i])

def gen_address_from_priv(priv_key_hex):
    key = ecdsa.SigningKey.from_string(binascii.unhexlify(priv_key_hex), curve=ecdsa.SECP256k1)
    pub_key = key.verifying_key.to_string("uncompressed")
    sha256_hash = hashlib.sha256(pub_key).digest()
    hash160 = RIPEMD160.new(sha256_hash).digest()
    addr_bytes = b'\x00' + hash160
    checksum = hashlib.sha256(hashlib.sha256(addr_bytes).digest()).digest()[:4]
    address = base58.b58encode(addr_bytes + checksum).decode()
    return address, hash160

# Seed
seed = "bitcoin2009-26094"

# Double SHA-256
priv_double = hashlib.sha256(hashlib.sha256(seed.encode()).digest()).hexdigest()
addr_double, hash160_double = gen_address_from_priv(priv_double)
ham_double = hamming_distance(hash160_double, TARGET_HASH160)
bytes_double = bytes_matching(hash160_double, TARGET_HASH160)
print("Double SHA-256:")
print(f"Priv: {priv_double}")
print(f"Address: {addr_double}")
print(f"Hash160: {hash160_double.hex()}")
print(f"Hamming: {ham_double}")
print(f"Bits: {160 - ham_double}/160 ({(160 - ham_double)/160:.2%})")
print(f"Bytes: {bytes_double}/20 ({bytes_double/20:.2%})")

# Concatenation
seed_part1 = "bitcoin2009"
seed_part2 = "-26094"
priv_concat = hashlib.sha256((seed_part1 + seed_part2).encode()).hexdigest()
addr_concat, hash160_concat = gen_address_from_priv(priv_concat)
ham_concat = hamming_distance(hash160_concat, TARGET_HASH160)
bytes_concat = bytes_matching(hash160_concat, TARGET_HASH160)
print("\nConcatenation:")
print(f"Priv: {priv_concat}")
print(f"Address: {addr_concat}")
print(f"Hash160: {hash160_concat.hex()}")
print(f"Hamming: {ham_concat}")
print(f"Bits: {160 - ham_concat}/160 ({(160 - ham_concat)/160:.2%})")
print(f"Bytes: {bytes_concat}/20 ({bytes_concat/20:.2%})")

# MD5
priv_md5 = hashlib.md5(seed.encode()).hexdigest() + "0" * 32
addr_md5, hash160_md5 = gen_address_from_priv(priv_md5)
ham_md5 = hamming_distance(hash160_md5, TARGET_HASH160)
bytes_md5 = bytes_matching(hash160_md5, TARGET_HASH160)
print("\nMD5:")
print(f"Priv: {priv_md5}")
print(f"Address: {addr_md5}")
print(f"Hash160: {hash160_md5.hex()}")
print(f"Hamming: {ham_md5}")
print(f"Bits: {160 - ham_md5}/160 ({(160 - ham_md5)/160:.
# Out:
#   File "<ipython-input-28-885b8a94bc1d>", line 66
#     print(f"Bits: {160 - ham_md5}/160 ({(160 - ham_md5)/160:.
#           ^
# SyntaxError: unterminated string literal (detected at line 66)

# %%
import hashlib
from Crypto.Hash import RIPEMD160
import ecdsa
import binascii
import base58

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")

def hamming_distance(b1, b2):
    return sum(bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1)))

def bytes_matching(b1, b2):
    return sum(1 for i in range(len(b1)) if b1[i] == b2[i])

def gen_address_from_priv(priv_key_hex):
    key = ecdsa.SigningKey.from_string(binascii.unhexlify(priv_key_hex), curve=ecdsa.SECP256k1)
    pub_key = key.verifying_key.to_string("uncompressed")
    sha256_hash = hashlib.sha256(pub_key).digest()
    hash160 = RIPEMD160.new(sha256_hash).digest()
    addr_bytes = b'\x00' + hash160
    checksum = hashlib.sha256(hashlib.sha256(addr_bytes).digest()).digest()[:4]
    address = base58.b58encode(addr_bytes + checksum).decode()
    return address, hash160

# Seed
seed = "bitcoin2009-26094"

# Double SHA-256
priv_double = hashlib.sha256(hashlib.sha256(seed.encode()).digest()).hexdigest()
addr_double, hash160_double = gen_address_from_priv(priv_double)
ham_double = hamming_distance(hash160_double, TARGET_HASH160)
bytes_double = bytes_matching(hash160_double, TARGET_HASH160)
print("Double SHA-256:")
print(f"Priv: {priv_double}")
print(f"Address: {addr_double}")
print(f"Hash160: {hash160_double.hex()}")
print(f"Hamming: {ham_double}")
print(f"Bits: {160 - ham_double}/160 ({(160 - ham_double)/160:.2%})")
print(f"Bytes: {bytes_double}/20 ({bytes_double/20:.2%})")

# Concatenation
seed_part1 = "bitcoin2009"
seed_part2 = "-26094"
priv_concat = hashlib.sha256((seed_part1 + seed_part2).encode()).hexdigest()
addr_concat, hash160_concat = gen_address_from_priv(priv_concat)
ham_concat = hamming_distance(hash160_concat, TARGET_HASH160)
bytes_concat = bytes_matching(hash160_concat, TARGET_HASH160)
print("\nConcatenation:")
print(f"Priv: {priv_concat}")
print(f"Address: {addr_concat}")
print(f"Hash160: {hash160_concat.hex()}")
print(f"Hamming: {ham_concat}")
print(f"Bits: {160 - ham_concat}/160 ({(160 - ham_concat)/160:.2%})")
print(f"Bytes: {bytes_concat}/20 ({bytes_concat/20:.2%})")

# MD5
priv_md5 = hashlib.md5(seed.encode()).hexdigest() + "0" * 32
addr_md5, hash160_md5 = gen_address_from_priv(priv_md5)
ham_md5 = hamming_distance(hash160_md5, TARGET_HASH160)
bytes_md5 = bytes_matching(hash160_md5, TARGET_HASH160)
print("\nMD5:")
print(f"Priv: {priv_md5}")
print(f"Address: {addr_md5}")
print(f"Hash160: {hash160_md5.hex()}")
print(f"Hamming: {ham_md5}")
print(f"Bits: {160 - ham_md5}/160 ({(160 - ham_md5)/160:.2%})")
print(f"Bytes: {bytes_md5}/20 ({bytes_md5/20:.2%})")

# Your Priv Key
priv_yours = "23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097"
addr_yours, hash160_yours = gen_address_from_priv(priv_yours)
ham_yours = hamming_distance(hash160_yours, TARGET_HASH160)
bytes_yours = bytes_matching(hash160_yours, TARGET_HASH160)
print("\nYour Priv Key:")
print(f"Priv: {priv_yours}")
print(f"Address: {addr_yours}")
print(f"Hash160: {hash160_yours.hex()}")
print(f"Hamming: {ham_yours}")
print(f"Bits: {160 - ham_yours}/160 ({(160 - ham_yours)/160:.2%})")
print(f"Bytes: {bytes_yours}/20 ({bytes_yours/20:.2%})")
# Out:
# Double SHA-256:
# Priv: 35ef412241fca23ecbabd2cda82e241aef553374dc1a5c3473c46efbf182c8f0
# Address: 13RkYUW8FTHmvxT4BPmMh5ukifPWra5EVN
# Hash160: 1a9e950d18ffd0f04c5c614c5bb27b2be050b479
# Hamming: 79
# Bits: 81/160 (50.62%)
# Bytes: 0/20 (0.00%)
#
# Concatenation:
# Priv: 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
# Address: 1LkELLo1HWFssMwNxvY6aDX3QxvFcCNyV1
# Hash160: d897680e59e95749d96de29522431bb4329e6c95
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)
#
# MD5:
# Priv: 6d0f799040bfb8f8318f5124027c83fe00000000000000000000000000000000
# Address: 13Jf4AWFto6FGj2QsTusHKKJWveS94yMtX
# Hash160: 194716d97d64f15e133532052c764fbf6953b981
# Hamming: 78
# Bits: 82/160 (51.25%)
# Bytes: 0/20 (0.00%)
#
# Your Priv Key:
# Priv: 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
# Address: 1LkELLo1HWFssMwNxvY6aDX3QxvFcCNyV1
# Hash160: d897680e59e95749d96de29522431bb4329e6c95
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)

# %%
import hashlib
from Crypto.Hash import RIPEMD160
import ecdsa
import binascii
import base58

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")

def hamming_distance(b1, b2):
    return sum(bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1)))

def bytes_matching(b1, b2):
    return sum(1 for i in range(len(b1)) if b1[i] == b2[i])

def gen_address_from_priv(priv_key_hex):
    key = ecdsa.SigningKey.from_string(binascii.unhexlify(priv_key_hex), curve=ecdsa.SECP256k1)
    pub_key = key.verifying_key.to_string("uncompressed")
    sha256_hash = hashlib.sha256(pub_key).digest()
    hash160 = RIPEMD160.new(sha256_hash).digest()
    addr_bytes = b'\x00' + hash160
    checksum = hashlib.sha256(hashlib.sha256(addr_bytes).digest()).digest()[:4]
    address = base58.b58encode(addr_bytes + checksum).decode()
    return address, hash160

# Seed
seed = "bitcoin2009-26094"

# Double SHA-256
priv_double = hashlib.sha256(hashlib.sha256(seed.encode()).digest()).hexdigest()
addr_double, hash160_double = gen_address_from_priv(priv_double)
ham_double = hamming_distance(hash160_double, TARGET_HASH160)
bytes_double = bytes_matching(hash160_double, TARGET_HASH160)
print("Double SHA-256:")
print(f"Priv: {priv_double}")
print(f"Address: {addr_double}")
print(f"Hash160: {hash160_double.hex()}")
print(f"Hamming: {ham_double}")
print(f"Bits: {160 - ham_double}/160 ({(160 - ham_double)/160:.2%})")
print(f"Bytes: {bytes_double}/20 ({bytes_double/20:.2%})")

# Concatenation
seed_part1 = "bitcoin2009"
seed_part2 = "-26094"
priv_concat = hashlib.sha256((seed_part1 + seed_part2).encode()).hexdigest()
addr_concat, hash160_concat = gen_address_from_priv(priv_concat)
ham_concat = hamming_distance(hash160_concat, TARGET_HASH160)
bytes_concat = bytes_matching(hash160_concat, TARGET_HASH160)
print("\nConcatenation:")
print(f"Priv: {priv_concat}")
print(f"Address: {addr_concat}")
print(f"Hash160: {hash160_concat.hex()}")
print(f"Hamming: {ham_concat}")
print(f"Bits: {160 - ham_concat}/160 ({(160 - ham_concat)/160:.2%})")
print(f"Bytes: {bytes_concat}/20 ({bytes_concat/20:.2%})")

# MD5 (SHA-256 of MD5)
priv_md5 = hashlib.sha256(hashlib.md5(seed.encode()).digest()).hexdigest()
addr_md5, hash160_md5 = gen_address_from_priv(priv_md5)
ham_md5 = hamming_distance(hash160_md5, TARGET_HASH160)
bytes_md5 = bytes_matching(hash160_md5, TARGET_HASH160)
print("\nMD5 (SHA-256 of MD5):")
print(f"Priv: {priv_md5}")
print(f"Address: {addr_md5}")
print(f"Hash160: {hash160_md5.hex()}")
print(f"Hamming: {ham_md5}")
print(f"Bits: {160 - ham_md5}/160 ({(160 - ham_md5)/160:.2%})")
print(f"Bytes: {bytes_md5}/20 ({bytes_md5/20:.2%})")

# Your Priv Key
priv_yours = "23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097"
addr_yours, hash160_yours = gen_address_from_priv(priv_yours)
ham_yours = hamming_distance(hash160_yours, TARGET_HASH160)
bytes_yours = bytes_matching(hash160_yours, TARGET_HASH160)
print("\nYour Priv Key:")
print(f"Priv: {priv_yours}")
print(f"Address: {addr_yours}")
print(f"Hash160: {hash160_yours.hex()}")
print(f"Hamming: {ham_yours}")
print(f"Bits: {160 - ham_yours}/160 ({(160 - ham_yours)/160:.2%})")
print(f"Bytes: {bytes_yours}/20 ({bytes_yours/20:.2%})")
# Out:
# Double SHA-256:
# Priv: 35ef412241fca23ecbabd2cda82e241aef553374dc1a5c3473c46efbf182c8f0
# Address: 13RkYUW8FTHmvxT4BPmMh5ukifPWra5EVN
# Hash160: 1a9e950d18ffd0f04c5c614c5bb27b2be050b479
# Hamming: 79
# Bits: 81/160 (50.62%)
# Bytes: 0/20 (0.00%)
#
# Concatenation:
# Priv: 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
# Address: 1LkELLo1HWFssMwNxvY6aDX3QxvFcCNyV1
# Hash160: d897680e59e95749d96de29522431bb4329e6c95
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)
#
# MD5 (SHA-256 of MD5):
# Priv: 4a217d462a0acd232c59e0d62ab3463fd8c09d6e2fc6a450587e0eb79a940060
# Address: 127W8eP8y3fCc26jRdoEvP5HmQoSaUpreY
# Hash160: 0c32f086e16fead9626564ce879ae7417ff01035
# Hamming: 82
# Bits: 78/160 (48.75%)
# Bytes: 0/20 (0.00%)
#
# Your Priv Key:
# Priv: 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
# Address: 1LkELLo1HWFssMwNxvY6aDX3QxvFcCNyV1
# Hash160: d897680e59e95749d96de29522431bb4329e6c95
# Hamming: 64
# Bits: 96/160 (60.00%)
# ...

# %%
import hashlib
from Crypto.Hash import RIPEMD160
import ecdsa
import binascii
import base58

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")

def hamming_distance(b1, b2):
    return sum(bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1)))

def bytes_matching(b1, b2):
    return sum(1 for i in range(len(b1)) if b1[i] == b2[i])

def gen_address_from_priv(priv_key_hex):
    key = ecdsa.SigningKey.from_string(binascii.unhexlify(priv_key_hex), curve=ecdsa.SECP256k1)
    pub_key = key.verifying_key.to_string("uncompressed")
    sha256_hash = hashlib.sha256(pub_key).digest()
    hash160 = RIPEMD160.new(sha256_hash).digest()
    addr_bytes = b'\x00' + hash160
    checksum = hashlib.sha256(hashlib.sha256(addr_bytes).digest()).digest()[:4]
    address = base58.b58encode(addr_bytes + checksum).decode()
    return address, hash160

# Seed
seed = "bitcoin2009-26094"

# Double SHA-256
priv_double = hashlib.sha256(hashlib.sha256(seed.encode()).digest()).hexdigest()
addr_double, hash160_double = gen_address_from_priv(priv_double)
ham_double = hamming_distance(hash160_double, TARGET_HASH160)
bytes_double = bytes_matching(hash160_double, TARGET_HASH160)
print("Double SHA-256:")
print(f"Priv: {priv_double}")
print(f"Address: {addr_double}")
print(f"Hash160: {hash160_double.hex()}")
print(f"Hamming: {ham_double}")
print(f"Bits: {160 - ham_double}/160 ({(160 - ham_double)/160:.2%})")
print(f"Bytes: {bytes_double}/20 ({bytes_double/20:.2%})")

# Concatenation (SHA-256)
seed_part1 = "bitcoin2009"
seed_part2 = "-26094"
priv_concat = hashlib.sha256((seed_part1 + seed_part2).encode()).hexdigest()
addr_concat, hash160_concat = gen_address_from_priv(priv_concat)
ham_concat = hamming_distance(hash160_concat, TARGET_HASH160)
bytes_concat = bytes_matching(hash160_concat, TARGET_HASH160)
print("\nConcatenation (SHA-256):")
print(f"Priv: {priv_concat}")
print(f"Address: {addr_concat}")
print(f"Hash160: {hash160_concat.hex()}")
print(f"Hamming: {ham_concat}")
print(f"Bits: {160 - ham_concat}/160 ({(160 - ham_concat)/160:.2%})")
print(f"Bytes: {bytes_concat}/20 ({bytes_concat/20:.2%})")

# MD5 (Raw)
priv_md5_raw = hashlib.md5(seed.encode()).hexdigest() + "0" * 32
addr_md5_raw, hash160_md5_raw = gen_address_from_priv(priv_md5_raw)
ham_md5_raw = hamming_distance(hash160_md5_raw, TARGET_HASH160)
bytes_md5_raw = bytes_matching(hash160_md5_raw, TARGET_HASH160)
print("\nMD5 (Raw):")
print(f"Priv: {priv_md5_raw}")
print(f"Address: {addr_md5_raw}")
print(f"Hash160: {hash160_md5_raw.hex()}")
print(f"Hamming: {ham_md5_raw}")
print(f"Bits: {160 - ham_md5_raw}/160 ({(160 - ham_md5_raw)/160:.2%})")
print(f"Bytes: {bytes_md5_raw}/20 ({bytes_md5_raw/20:.2%})")

# MD5 (SHA-256 of MD5)
priv_md5_sha = hashlib.sha256(hashlib.md5(seed.encode()).digest()).hexdigest()
addr_md5_sha, hash160_md5_sha = gen_address_from_priv(priv_md5_sha)
ham_md5_sha = hamming_distance(hash160_md5_sha, TARGET_HASH160)
bytes_md5_sha = bytes_matching(hash160_md5_sha, TARGET_HASH160)
print("\nMD5 (SHA-256 of MD5):")
print(f"Priv: {priv_md5_sha}")
print(f"Address: {addr_md5_sha}")
print(f"Hash160: {hash160_md5_sha.hex()}")
print(f"Hamming: {ham_md5_sha}")
print(f"Bits: {160 - ham_md5_sha}/160 ({(160 - ham_md5_sha)/160:.2%})")
print(f"Bytes: {bytes_md5_sha}/20 ({bytes_md5_sha/20:.2%})")

# Your Priv Key
priv_yours = "23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097"
addr_yours, hash160_yours = gen_address_from_priv(priv_yours)
ham_yours = hamming_distance(hash160_yours, TARGET_HASH160)
bytes_yours = bytes_matching(hash160_yours, TARGET_HASH160)
print("\nYour Priv Key:")
print(f"Priv: {priv_yours}")
print(f"Address: {addr_yours}")
print(f"Hash160: {hash160_yours.hex()}")
print(f"Hamming: {ham_yours}")
print(f"Bits: {160 - ham_yours}/160 ({(160 - ham_yours)/160:.2%})")
print(f"Bytes: {bytes_yours}/20 ({bytes_yours/20:.2%})")
# Out:
# Double SHA-256:
# Priv: 35ef412241fca23ecbabd2cda82e241aef553374dc1a5c3473c46efbf182c8f0
# Address: 13RkYUW8FTHmvxT4BPmMh5ukifPWra5EVN
# Hash160: 1a9e950d18ffd0f04c5c614c5bb27b2be050b479
# Hamming: 79
# Bits: 81/160 (50.62%)
# Bytes: 0/20 (0.00%)
#
# Concatenation (SHA-256):
# Priv: 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
# Address: 1LkELLo1HWFssMwNxvY6aDX3QxvFcCNyV1
# Hash160: d897680e59e95749d96de29522431bb4329e6c95
# Hamming: 64
# Bits: 96/160 (60.00%)
# Bytes: 4/20 (20.00%)
#
# MD5 (Raw):
# Priv: 6d0f799040bfb8f8318f5124027c83fe00000000000000000000000000000000
# Address: 13Jf4AWFto6FGj2QsTusHKKJWveS94yMtX
# Hash160: 194716d97d64f15e133532052c764fbf6953b981
# Hamming: 78
# Bits: 82/160 (51.25%)
# Bytes: 0/20 (0.00%)
#
# MD5 (SHA-256 of MD5):
# Priv: 4a217d462a0acd232c59e0d62ab3463fd8c09d6e2fc6a450587e0eb79a940060
# Address: 127W8eP8y3fCc26jRdoEvP5HmQoSaUpreY
# Hash160: 0c32f086e16fead9626564ce879ae7417ff01035
# Hamming: 82
# Bits: 78/160 (48.75%)
# ...

# %%
import hashlib
from Crypto.Hash import RIPEMD160
import ecdsa
import binascii
import base58

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")

def hamming_distance(b1, b2):
    print(f"\nHamming Distance Calc:")
    print(f"b1 (Target): {b1.hex()}")
    print(f"b2 (Test):   {b2.hex()}")
    diffs = [bin(b1[i] ^ b2[i]).count('1') for i in range(len(b1))]
    for i, diff in enumerate(diffs):
        print(f"Byte {i}: {hex(b1[i])} ^ {hex(b2[i])} = {hex(b1[i] ^ b2[i])} ({diff} bits)")
    total = sum(diffs)
    print(f"Total Hamming: {total}")
    return total

def bytes_matching(b1, b2):
    matches = sum(1 for i in range(len(b1)) if b1[i] == b2[i])
    print(f"Bytes Matching: {matches}/{len(b1)}")
    return matches

def gen_address_from_priv(priv_key_hex):
    print(f"\nGenerating Address from Priv Key: {priv_key_hex}")
    key = ecdsa.SigningKey.from_string(binascii.unhexlify(priv_key_hex), curve=ecdsa.SECP256k1)
    pub_key = key.verifying_key.to_string("uncompressed")
    print(f"Pub Key (uncompressed): {pub_key.hex()[:20]}... (len: {len(pub_key)})")
    sha256_hash = hashlib.sha256(pub_key).digest()
    print(f"SHA-256(Pub): {sha256_hash.hex()}")
    hash160 = RIPEMD160.new(sha256_hash).digest()
    print(f"Hash160: {hash160.hex()}")
    addr_bytes = b'\x00' + hash160
    checksum = hashlib.sha256(hashlib.sha256(addr_bytes).digest()).digest()[:4]
    print(f"Checksum: {checksum.hex()}")
    address = base58.b58encode(addr_bytes + checksum).decode()
    print(f"Address: {address}")
    return address, hash160

# Seed
seed = "bitcoin2009-26094"
print(f"\nSeed: {seed}")

# Double SHA-256
print("\n--- Double SHA-256 ---")
sha1 = hashlib.sha256(seed.encode()).digest()
print(f"SHA-256(Seed): {sha1.hex()}")
priv_double = hashlib.sha256(sha1).hexdigest()
addr_double, hash160_double = gen_address_from_priv(priv_double)
ham_double = hamming_distance(hash160_double, TARGET_HASH160)
bytes_double = bytes_matching(hash160_double, TARGET_HASH160)
print(f"\nDouble SHA-256 Summary:")
print(f"Priv: {priv_double}")
print(f"Address: {addr_double}")
print(f"Hash160: {hash160_double.hex()}")
print(f"Hamming: {ham_double}")
print(f"Bits: {160 - ham_double}/160 ({(160 - ham_double)/160:.2%})")
print(f"Bytes: {bytes_double}/20 ({bytes_double/20:.2%})")

# Concatenation (SHA-256)
print("\n--- Concatenation (SHA-256) ---")
seed_part1 = "bitcoin2009"
seed_part2 = "-26094"
concat_seed = seed_part1 + seed_part2
print(f"Concatenated Seed: {concat_seed}")
priv_concat = hashlib.sha256(concat_seed.encode()).hexdigest()
addr_concat, hash160_concat = gen_address_from_priv(priv_concat)
ham_concat = hamming_distance(hash160_concat, TARGET_HASH160)
bytes_concat = bytes_matching(hash160_concat, TARGET_HASH160)
print(f"\nConcatenation Summary:")
print(f"Priv: {priv_concat}")
print(f"Address: {addr_concat}")
print(f"Hash160: {hash160_concat.hex()}")
print(f"Hamming: {ham_concat}")
print(f"Bits: {160 - ham_concat}/160 ({(160 - ham_concat)/160:.2%})")
print(f"Bytes: {bytes_concat}/20 ({bytes_concat/20:.2%})")

# MD5 (Raw)
print("\n--- MD5 (Raw) ---")
md5_raw = hashlib.md5(seed.encode()).digest()
print(f"MD5(Seed): {md5_raw.hex()}")
priv_md5_raw = md5_raw.hex() + "0" * 32
addr_md5_raw, hash160_md5_raw = gen_address_from_priv(priv_md5_raw)
ham_md5_raw = hamming_distance(hash160_md5_raw, TARGET_HASH160)
bytes_md5_raw = bytes_matching(hash160_md5_raw, TARGET_HASH160)
print(f"\nMD5 (Raw) Summary:")
print(f"Priv: {priv_md5_raw}")
print(f"Address: {addr_md5_raw}")
print(f"Hash160: {hash160_md5_raw.hex()}")
print(f"Hamming: {ham_md5_raw}")
print(f"Bits: {160 - ham_md5_raw}/160 ({(160 - ham_md5_raw)/160:.2%})")
print(f"Bytes: {bytes_md5_raw}/20 ({bytes_md5_raw/20:.2%})")

# MD5 (SHA-256 of MD5)
print("\n--- MD5 (SHA-256 of MD5) ---")
md5_sha = hashlib.md5(seed.encode()).digest()
print(f"MD5(Seed): {md5_sha.hex()}")
priv_md5_sha = hashlib.sha256(md5_sha).hexdigest()
addr_md5_sha, hash160_md5_sha = gen_address_from_priv(priv_md5_sha)
ham_md5_sha = hamming_distance(hash160_md5_sha, TARGET_HASH160)
bytes_md5_sha = bytes_matching(hash160_md5_sha, TARGET_HASH160)
print(f"\nMD5 (SHA-256 of MD5) Summary:")
print(f"Priv: {priv_md5_sha}")
print(f"Address: {addr_md5_sha}")
print(f"Hash160: {hash160_md5_sha.hex()}")
print(f"Hamming: {ham_md5_sha}")
print(f"Bits: {160 - ham_md5_sha}/160 ({(160 - ham_md5_sha)/160:.2%})")
print(f"Bytes: {bytes_md5_sha}/20 ({bytes_md5_sha/20:.2%})")

# Plaintext SHA-256 (Old-School BTC Core)
print("\n--- Plaintext SHA-256 (Old-School BTC Core) ---")
priv_plain = hashlib.sha256(seed.encode()).hexdigest()
addr_plain, hash160_plain = gen_address_from_priv(priv_plain)
ham_plain = hamming_distance(hash160_plain, TARGET_HASH160)
bytes_plain = bytes_matching(hash160_plain, TARGET_HASH160)
print(f"\nPlaintext SHA-256 Summary:")
print(f"Priv: {priv_plain}")
print(f"Address: {addr_plain}")
print(f"Hash160: {hash160_plain.hex()}")
print(f"Hamming: {ham_plain}")
print(f"Bits: {160 - ham_plain}/160 ({(160 - ham_plain)/160:.2%})")
print(f"Bytes: {bytes_plain}/20 ({bytes_plain/20:.2%})")

# Your Priv Key
print("\n--- Your Priv Key ---")
priv_yours = "23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097"
addr_yours, hash160_yours = gen_address_from_priv(priv_yours)
ham_yours = hamming_distance(hash160_yours, TARGET_HASH160)
bytes_yours = bytes_matching(hash160_yours, TARGET_HASH160)
print(f"\nYour Priv Key Summary:")
print(f"Priv: {priv_yours}")
print(f"Address: {addr_yours}")
print(f"Hash160: {hash160_yours.hex()}")
print(f"Hamming: {ham_yours}")
print(f"Bits: {160 - ham_yours}/160 ({(160 - ham_yours)/160:.2%})")
print(f"Bytes: {bytes_yours}/20 ({bytes_yours/20:.2%})")
# Out:
# Seed: bitcoin2009-26094
#
# --- Double SHA-256 ---
# SHA-256(Seed): 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
#
# Generating Address from Priv Key: 35ef412241fca23ecbabd2cda82e241aef553374dc1a5c3473c46efbf182c8f0
# Pub Key (uncompressed): 04fffa543e1ecad3655f... (len: 65)
# SHA-256(Pub): 588e811fb38505fafdfc89c2ee1abb4e62c554e21501fe76d28b67b75ca88813
# Hash160: 1a9e950d18ffd0f04c5c614c5bb27b2be050b479
# Checksum: 09b384d1
# Address: 13RkYUW8FTHmvxT4BPmMh5ukifPWra5EVN
#
# Hamming Distance Calc:
# b1 (Target): 1a9e950d18ffd0f04c5c614c5bb27b2be050b479
# b2 (Test):   a0b0d60e5991578ed37cbda2b17d8b2ce23ab295
# Byte 0: 0x1a ^ 0xa0 = 0xba (5 bits)
# Byte 1: 0x9e ^ 0xb0 = 0x2e (4 bits)
# Byte 2: 0x95 ^ 0xd6 = 0x43 (3 bits)
# Byte 3: 0xd ^ 0xe = 0x3 (2 bits)
# Byte 4: 0x18 ^ 0x59 = 0x41 (2 bits)
# Byte 5: 0xff ^ 0x91 = 0x6e (5 bits)
# Byte 6: 0xd0 ^ 0x57 = 0x87 (4 bits)
# Byte 7: 0xf0 ^ 0x8e = 0x7e (6 bits)
# Byte 8: 0x4c ^ 0xd3 = 0x9f (6 bits)
# ...

# %%
import hashlib
from Crypto.Hash import RIPEMD160
import ecdsa
import binascii
import base58

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")
TARGET_ADDRESS = "1FeexV6bAHb8ybZjqQMjJrcCrHGW9sb6uF"

def hamming_distance(b1, b2, label=""):
    print(f"\nHamming Distance Calc ({label}):")
    print(f"b1: {b1.hex() if isinstance(b1, bytes) else b1}")
    print(f"b2: {b2.hex() if isinstance(b2, bytes) else b2}")
    if isinstance(b1, str):
        b1 = b1.encode()
        b2 = b2.encode()
    diffs = [bin(b1[i] ^ b2[i]).count('1') for i in range(min(len(b1), len(b2)))]
    for i, diff in enumerate(diffs):
        print(f"Byte {i}: {hex(b1[i])} ^ {hex(b2[i])} = {hex(b1[i] ^ b2[i])} ({diff} bits)")
    total = sum(diffs)
    print(f"Total Hamming: {total}")
    return total

def bytes_matching(b1, b2):
    matches = sum(1 for i in range(min(len(b1), len(b2))) if b1[i] == b2[i])
    return matches

def gen_address_from_priv(priv_key_hex):
    key = ecdsa.SigningKey.from_string(binascii.unhexlify(priv_key_hex), curve=ecdsa.SECP256k1)
    pub_key = key.verifying_key.to_string("uncompressed")
    sha256_hash = hashlib.sha256(pub_key).digest()
    hash160 = RIPEMD160.new(sha256_hash).digest()
    addr_bytes = b'\x00' + hash160
    checksum = hashlib.sha256(hashlib.sha256(addr_bytes).digest()).digest()[:4]
    address = base58.b58encode(addr_bytes + checksum).decode()
    return address, hash160, pub_key

seed = "bitcoin2009-26094"
print(f"Seed: {seed}")
print(f"Vecna SHA-256(Seed): {hashlib.sha256(seed.encode()).hexdigest()}")

# Double SHA-256
priv_double = "35ef412241fca23ecbabd2cda82e241aef553374dc1a5c3473c46efbf182c8f0"
addr_double, hash160_double, pub_double = gen_address_from_priv(priv_double)
ham_addr_double = hamming_distance(TARGET_ADDRESS, addr_double, "Address (Target=Goal)")
ham_hash_double = hamming_distance(TARGET_HASH160, hash160_double, "Hash160 (Target=Goal)")
ham_pub_double = hamming_distance(binascii.unhexlify("04"), pub_double, "PubKey (Prefix Only)")
print(f"\nDouble SHA-256 Summary:")
print(f"Priv: {priv_double}")
print(f"Address: {addr_double}")
print(f"Hash160: {hash160_double.hex()}")
print(f"PubKey: {pub_double.hex()[:20]}... (len: {len(pub_double)})")
print(f"Hamming (Address): {ham_addr_double}")
print(f"Hamming (Hash160): {ham_hash_double}")
print(f"Hamming (PubKey Prefix): {ham_pub_double}")
print(f"Bytes: {bytes_matching(hash160_double, TARGET_HASH160)}/20")

# Your Priv Key (Concat/Plaintext)
priv_yours = "23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097"
addr_yours, hash160_yours, pub_yours = gen_address_from_priv(priv_yours)
ham_addr_yours = hamming_distance(TARGET_ADDRESS, addr_yours, "Address (Target=Goal)")
ham_hash_yours_my = hamming_distance(TARGET_HASH160, hash160_yours, "Hash160 (Target=Goal)")
ham_hash_yours_your = hamming_distance(hash160_yours, TARGET_HASH160, "Hash160 (Jed’s Way)")
ham_pub_yours = hamming_distance(binascii.unhexlify("04"), pub_yours, "PubKey (Prefix Only)")
print(f"\nYour Priv Key (Concat/Plaintext) Summary:")
print(f"Priv: {priv_yours}")
print(f"Address: {addr_yours}")
print(f"Hash160: {hash160_yours.hex()}")
print(f"PubKey: {pub_yours.hex()[:20]}... (len: {len(pub_yours)})")
print(f"Hamming (Address): {ham_addr_yours}")
print(f"Hamming (Hash160, Vecna): {ham_hash_yours_my}")
print(f"Hamming (Hash160, Jed): {ham_hash_yours_your}")
print(f"Hamming (PubKey Prefix): {ham_pub_yours}")
print(f"Bytes: {bytes_matching(hash160_yours, TARGET_HASH160)}/20")
# Out:
# Seed: bitcoin2009-26094
# Vecna SHA-256(Seed): 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
#
# Hamming Distance Calc (Address (Target=Goal)):
# b1: 1FeexV6bAHb8ybZjqQMjJrcCrHGW9sb6uF
# b2: 13RkYUW8FTHmvxT4BPmMh5ukifPWra5EVN
# Byte 0: 0x31 ^ 0x31 = 0x0 (0 bits)
# Byte 1: 0x46 ^ 0x33 = 0x75 (5 bits)
# Byte 2: 0x65 ^ 0x52 = 0x37 (5 bits)
# Byte 3: 0x65 ^ 0x6b = 0xe (3 bits)
# Byte 4: 0x78 ^ 0x59 = 0x21 (2 bits)
# Byte 5: 0x56 ^ 0x55 = 0x3 (2 bits)
# Byte 6: 0x36 ^ 0x57 = 0x61 (3 bits)
# Byte 7: 0x62 ^ 0x38 = 0x5a (4 bits)
# Byte 8: 0x41 ^ 0x46 = 0x7 (3 bits)
# Byte 9: 0x48 ^ 0x54 = 0x1c (3 bits)
# Byte 10: 0x62 ^ 0x48 = 0x2a (3 bits)
# Byte 11: 0x38 ^ 0x6d = 0x55 (4 bits)
# Byte 12: 0x79 ^ 0x76 = 0xf (4 bits)
# Byte 13: 0x62 ^ 0x78 = 0x1a (3 bits)
# Byte 14: 0x5a ^ 0x54 = 0xe (3 bits)
# Byte 15: 0x6a ^ 0x34 = 0x5e (5 bits)
# Byte 16: 0x71 ^ 0x42 = 0x33 (4 bits)
# Byte 17: 0x51 ^ 0x50 = 0x1 (1 bits)
# Byte 18: 0x4d ^ 0x6d = 0x20 (1 bits)
# ...

# %%
import hashlib
from Crypto.Hash import RIPEMD160
import ecdsa
import binascii
import base58

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")
TARGET_ADDRESS = "1FeexV6bAHb8ybZjqQMjJrcCrHGW9sb6uF"

def hamming_distance(b1, b2, label=""):
    print(f"\nHamming Distance Calc ({label}):")
    print(f"b1: {b1.hex() if isinstance(b1, bytes) else b1}")
    print(f"b2: {b2.hex() if isinstance(b2, bytes) else b2}")
    if isinstance(b1, str):
        b1 = b1.encode()
        b2 = b2.encode()
    diffs = [bin(b1[i] ^ b2[i]).count('1') for i in range(min(len(b1), len(b2)))]
    for i, diff in enumerate(diffs):
        print(f"Byte {i}: {hex(b1[i])} ^ {hex(b2[i])} = {hex(b1[i] ^ b2[i])} ({diff} bits)")
    total = sum(diffs)
    print(f"Total Hamming: {total}")
    return total

def bytes_matching(b1, b2):
    matches = sum(1 for i in range(min(len(b1), len(b2))) if b1[i] == b2[i])
    return matches

def gen_address_from_priv(priv_key_hex):
    key = ecdsa.SigningKey.from_string(binascii.unhexlify(priv_key_hex), curve=ecdsa.SECP256k1)
    pub_key = key.verifying_key.to_string("uncompressed")
    sha256_hash = hashlib.sha256(pub_key).digest()
    hash160 = RIPEMD160.new(sha256_hash).digest()
    addr_bytes = b'\x00' + hash160
    checksum = hashlib.sha256(hashlib.sha256(addr_bytes).digest()).digest()[:4]
    address = base58.b58encode(addr_bytes + checksum).decode()
    return address, hash160, pub_key

seed = "bitcoin2009-26094"
print(f"Seed: {seed}")
print(f"Vecna SHA-256(Seed): {hashlib.sha256(seed.encode()).hexdigest()}")

# Double SHA-256
priv_double = "35ef412241fca23ecbabd2cda82e241aef553374dc1a5c3473c46efbf182c8f0"
addr_double, hash160_double, pub_double = gen_address_from_priv(priv_double)
ham_addr_double = hamming_distance(TARGET_ADDRESS, addr_double, "Address (Target=Goal)")
ham_hash_double = hamming_distance(TARGET_HASH160, hash160_double, "Hash160 (Target=Goal)")
ham_hash_double_jed = hamming_distance(hash160_double, TARGET_HASH160, "Hash160 (Jed’s Way)")
print(f"\nDouble SHA-256 Summary:")
print(f"Priv: {priv_double}")
print(f"Address: {addr_double}")
print(f"Hash160: {hash160_double.hex()}")
print(f"Hamming (Address): {ham_addr_double}")
print(f"Hamming (Hash160, Vecna): {ham_hash_double}")
print(f"Hamming (Hash160, Jed): {ham_hash_double_jed}")
print(f"Bytes: {bytes_matching(hash160_double, TARGET_HASH160)}/20")

# Your Priv Key (Concat/Plaintext)
priv_yours = "23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097"
addr_yours, hash160_yours, pub_yours = gen_address_from_priv(priv_yours)
ham_addr_yours = hamming_distance(TARGET_ADDRESS, addr_yours, "Address (Target=Goal)")
ham_hash_yours_my = hamming_distance(TARGET_HASH160, hash160_yours, "Hash160 (Target=Goal)")
ham_hash_yours_jed = hamming_distance(hash160_yours, TARGET_HASH160, "Hash160 (Jed’s Way)")
print(f"\nYour Priv Key (Concat/Plaintext) Summary:")
print(f"Priv: {priv_yours}")
print(f"Address: {addr_yours}")
print(f"Hash160: {hash160_yours.hex()}")
print(f"Hamming (Address): {ham_addr_yours}")
print(f"Hamming (Hash160, Vecna): {ham_hash_yours_my}")
print(f"Hamming (Hash160, Jed): {ham_hash_yours_jed}")
print(f"Bytes: {bytes_matching(hash160_yours, TARGET_HASH160)}/20")
# Out:
# Seed: bitcoin2009-26094
# Vecna SHA-256(Seed): 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
#
# Hamming Distance Calc (Address (Target=Goal)):
# b1: 1FeexV6bAHb8ybZjqQMjJrcCrHGW9sb6uF
# b2: 13RkYUW8FTHmvxT4BPmMh5ukifPWra5EVN
# Byte 0: 0x31 ^ 0x31 = 0x0 (0 bits)
# Byte 1: 0x46 ^ 0x33 = 0x75 (5 bits)
# Byte 2: 0x65 ^ 0x52 = 0x37 (5 bits)
# Byte 3: 0x65 ^ 0x6b = 0xe (3 bits)
# Byte 4: 0x78 ^ 0x59 = 0x21 (2 bits)
# Byte 5: 0x56 ^ 0x55 = 0x3 (2 bits)
# Byte 6: 0x36 ^ 0x57 = 0x61 (3 bits)
# Byte 7: 0x62 ^ 0x38 = 0x5a (4 bits)
# Byte 8: 0x41 ^ 0x46 = 0x7 (3 bits)
# Byte 9: 0x48 ^ 0x54 = 0x1c (3 bits)
# Byte 10: 0x62 ^ 0x48 = 0x2a (3 bits)
# Byte 11: 0x38 ^ 0x6d = 0x55 (4 bits)
# Byte 12: 0x79 ^ 0x76 = 0xf (4 bits)
# Byte 13: 0x62 ^ 0x78 = 0x1a (3 bits)
# Byte 14: 0x5a ^ 0x54 = 0xe (3 bits)
# Byte 15: 0x6a ^ 0x34 = 0x5e (5 bits)
# Byte 16: 0x71 ^ 0x42 = 0x33 (4 bits)
# Byte 17: 0x51 ^ 0x50 = 0x1 (1 bits)
# Byte 18: 0x4d ^ 0x6d = 0x20 (1 bits)
# ...

# %%
import hashlib
from Crypto.Hash import RIPEMD160
import ecdsa
import binascii
import base58

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")
TARGET_ADDRESS = "1FeexV6bAHb8ybZjqQMjJrcCrHGW9sb6uF"

def hamming_distance(b1, b2, label=""):
    print(f"\nHamming Distance Calc ({label}):")
    print(f"b1: {b1.hex() if isinstance(b1, bytes) else b1}")
    print(f"b2: {b2.hex() if isinstance(b2, bytes) else b2}")
    if isinstance(b1, str):
        b1 = b1.encode()
        b2 = b2.encode()
    diffs = [bin(b1[i] ^ b2[i]).count('1') for i in range(min(len(b1), len(b2)))]
    for i, diff in enumerate(diffs):
        print(f"Byte {i}: {hex(b1[i])} ^ {hex(b2[i])} = {hex(b1[i] ^ b2[i])} ({diff} bits)")
    total = sum(diffs)
    print(f"Total Hamming: {total}")
    return total

def bytes_matching(b1, b2):
    matches = sum(1 for i in range(min(len(b1), len(b2))) if b1[i] == b2[i])
    return matches

def gen_address_from_priv(priv_key_hex):
    key = ecdsa.SigningKey.from_string(binascii.unhexlify(priv_key_hex), curve=ecdsa.SECP256k1)
    pub_key = key.verifying_key.to_string("uncompressed")
    sha256_hash = hashlib.sha256(pub_key).digest()
    hash160 = RIPEMD160.new(sha256_hash).digest()
    addr_bytes = b'\x00' + hash160
    checksum = hashlib.sha256(hashlib.sha256(addr_bytes).digest()).digest()[:4]
    address = base58.b58encode(addr_bytes + checksum).decode()
    return address, hash160

seed = "bitcoin2009-26094"
print(f"Seed: {seed}")
print(f"Vecna SHA-256(Seed): {hashlib.sha256(seed.encode()).hexdigest()}")

# Double SHA-256
priv_double = "35ef412241fca23ecbabd2cda82e241aef553374dc1a5c3473c46efbf182c8f0"
addr_double, hash160_double = gen_address_from_priv(priv_double)
ham_addr_double = hamming_distance(TARGET_ADDRESS, addr_double, "Address (Target=Goal)")
ham_hash_double = hamming_distance(TARGET_HASH160, hash160_double, "Hash160 (Target=Goal)")
ham_hash_double_jed = hamming_distance(hash160_double, TARGET_HASH160, "Hash160 (Jed’s Way)")
print(f"\nDouble SHA-256 Summary:")
print(f"Priv: {priv_double}")
print(f"Address: {addr_double}")
print(f"Hash160: {hash160_double.hex()}")
print(f"Hamming (Address): {ham_addr_double}")
print(f"Hamming (Hash160, Vecna): {ham_hash_double}")
print(f"Hamming (Hash160, Jed): {ham_hash_double_jed}")
print(f"Bytes: {bytes_matching(hash160_double, TARGET_HASH160)}/20")

# Your Priv Key (Concat/Plaintext)
priv_yours = "23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097"
addr_yours, hash160_yours = gen_address_from_priv(priv_yours)
ham_addr_yours = hamming_distance(TARGET_ADDRESS, addr_yours, "Address (Target=Goal)")
ham_hash_yours_my = hamming_distance(TARGET_HASH160, hash160_yours, "Hash160 (Target=Goal)")
ham_hash_yours_jed = hamming_distance(hash160_yours, TARGET_HASH160, "Hash160 (Jed’s Way)")
print(f"\nYour Priv Key (Concat/Plaintext) Summary:")
print(f"Priv: {priv_yours}")
print(f"Address: {addr_yours}")
print(f"Hash160: {hash160_yours.hex()}")
print(f"Hamming (Address): {ham_addr_yours}")
print(f"Hamming (Hash160, Vecna): {ham_hash_yours_my}")
print(f"Hamming (Hash160, Jed): {ham_hash_yours_jed}")
print(f"Bytes: {bytes_matching(hash160_yours, TARGET_HASH160)}/20")
# Out:
# Seed: bitcoin2009-26094
# Vecna SHA-256(Seed): 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
#
# Hamming Distance Calc (Address (Target=Goal)):
# b1: 1FeexV6bAHb8ybZjqQMjJrcCrHGW9sb6uF
# b2: 13RkYUW8FTHmvxT4BPmMh5ukifPWra5EVN
# Byte 0: 0x31 ^ 0x31 = 0x0 (0 bits)
# Byte 1: 0x46 ^ 0x33 = 0x75 (5 bits)
# Byte 2: 0x65 ^ 0x52 = 0x37 (5 bits)
# Byte 3: 0x65 ^ 0x6b = 0xe (3 bits)
# Byte 4: 0x78 ^ 0x59 = 0x21 (2 bits)
# Byte 5: 0x56 ^ 0x55 = 0x3 (2 bits)
# Byte 6: 0x36 ^ 0x57 = 0x61 (3 bits)
# Byte 7: 0x62 ^ 0x38 = 0x5a (4 bits)
# Byte 8: 0x41 ^ 0x46 = 0x7 (3 bits)
# Byte 9: 0x48 ^ 0x54 = 0x1c (3 bits)
# Byte 10: 0x62 ^ 0x48 = 0x2a (3 bits)
# Byte 11: 0x38 ^ 0x6d = 0x55 (4 bits)
# Byte 12: 0x79 ^ 0x76 = 0xf (4 bits)
# Byte 13: 0x62 ^ 0x78 = 0x1a (3 bits)
# Byte 14: 0x5a ^ 0x54 = 0xe (3 bits)
# Byte 15: 0x6a ^ 0x34 = 0x5e (5 bits)
# Byte 16: 0x71 ^ 0x42 = 0x33 (4 bits)
# Byte 17: 0x51 ^ 0x50 = 0x1 (1 bits)
# Byte 18: 0x4d ^ 0x6d = 0x20 (1 bits)
# ...

# %%
import hashlib
from Crypto.Hash import RIPEMD160
import ecdsa
import binascii
import base58

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")
TARGET_ADDRESS = "1FeexV6bAHb8ybZjqQMjJrcCrHGW9sb6uF"

def hamming_distance(b1, b2, label=""):
    print(f"\nHamming Distance Calc ({label}):")
    print(f"b1: {b1.hex() if isinstance(b1, bytes) else b1}")
    print(f"b2: {b2.hex() if isinstance(b2, bytes) else b2}")
    if isinstance(b1, str):
        b1 = b1.encode()
        b2 = b2.encode()
    diffs = [bin(b1[i] ^ b2[i]).count('1') for i in range(min(len(b1), len(b2)))]
    for i, diff in enumerate(diffs):
        print(f"Byte {i}: {hex(b1[i])} ^ {hex(b2[i])} = {hex(b1[i] ^ b2[i])} ({diff} bits)")
    total = sum(diffs)
    print(f"Total Hamming: {total}")
    return total

def bytes_matching(b1, b2):
    matches = sum(1 for i in range(min(len(b1), len(b2))) if b1[i] == b2[i])
    return matches

def gen_address_from_priv(priv_key_hex):
    key = ecdsa.SigningKey.from_string(binascii.unhexlify(priv_key_hex), curve=ecdsa.SECP256k1)
    pub_key = key.verifying_key.to_string("uncompressed")
    sha256_hash = hashlib.sha256(pub_key).digest()
    hash160 = RIPEMD160.new(sha256_hash).digest()
    addr_bytes = b'\x00' + hash160
    checksum = hashlib.sha256(hashlib.sha256(addr_bytes).digest()).digest()[:4]
    address = base58.b58encode(addr_bytes + checksum).decode()
    return address, hash160

seed = "bitcoin2009-26094"
print(f"Seed: {seed}")
print(f"Vecna SHA-256(Seed): {hashlib.sha256(seed.encode()).hexdigest()}")

# Double SHA-256
priv_double = "35ef412241fca23ecbabd2cda82e241aef553374dc1a5c3473c46efbf182c8f0"
addr_double, hash160_double = gen_address_from_priv(priv_double)
ham_addr_double = hamming_distance(TARGET_ADDRESS, addr_double, "Address (Target=Goal)")
ham_hash_double = hamming_distance(TARGET_HASH160, hash160_double, "Hash160 (Target=Goal)")
ham_hash_double_jed = hamming_distance(hash160_double, TARGET_HASH160, "Hash160 (Jed’s Way)")
print(f"\nDouble SHA-256 Summary:")
print(f"Priv: {priv_double}")
print(f"Address: {addr_double}")
print(f"Hash160: {hash160_double.hex()}")
print(f"Hamming (Address): {ham_addr_double}")
print(f"Hamming (Hash160, Vecna): {ham_hash_double}")
print(f"Hamming (Hash160, Jed): {ham_hash_double_jed}")
print(f"Bytes: {bytes_matching(hash160_double, TARGET_HASH160)}/20")

# Your Priv Key (Concat/Plaintext)
priv_yours = "23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097"
addr_yours, hash160_yours = gen_address_from_priv(priv_yours)
ham_addr_yours = hamming_distance(TARGET_ADDRESS, addr_yours, "Address (Target=Goal)")
ham_hash_yours_my = hamming_distance(TARGET_HASH160, hash160_yours, "Hash160 (Target=Goal)")
ham_hash_yours_jed = hamming_distance(hash160_yours, TARGET_HASH160, "Hash160 (Jed’s Way)")
print(f"\nYour Priv Key (Concat/Plaintext) Summary:")
print(f"Priv: {priv_yours}")
print(f"Address: {addr_yours}")
print(f"Hash160: {hash160_yours.hex()}")
print(f"Hamming (Address): {ham_addr_yours}")
print(f"Hamming (Hash160, Vecna): {ham_hash_yours_my}")
print(f"Hamming (Hash160, Jed): {ham_hash_yours_jed}")
print(f"Bytes: {bytes_matching(hash160_yours, TARGET_HASH160)}/20")

# XOR Test
s1 = binascii.unhexlify("e3feda4138d83f60b66f2c1ebfa5f70a8f684ea8eabf0ebfa7aeadbb2e69eabf")
s2 = binascii.unhexlify("23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097")
xor_key = bytes(a ^ b for a, b in zip(s1, s2))
print(f"\nXOR of Standard SHA-256 and Your Priv: {xor_key.hex()}")
# Out:
# Seed: bitcoin2009-26094
# Vecna SHA-256(Seed): 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
#
# Hamming Distance Calc (Address (Target=Goal)):
# b1: 1FeexV6bAHb8ybZjqQMjJrcCrHGW9sb6uF
# b2: 13RkYUW8FTHmvxT4BPmMh5ukifPWra5EVN
# Byte 0: 0x31 ^ 0x31 = 0x0 (0 bits)
# Byte 1: 0x46 ^ 0x33 = 0x75 (5 bits)
# Byte 2: 0x65 ^ 0x52 = 0x37 (5 bits)
# Byte 3: 0x65 ^ 0x6b = 0xe (3 bits)
# Byte 4: 0x78 ^ 0x59 = 0x21 (2 bits)
# Byte 5: 0x56 ^ 0x55 = 0x3 (2 bits)
# Byte 6: 0x36 ^ 0x57 = 0x61 (3 bits)
# Byte 7: 0x62 ^ 0x38 = 0x5a (4 bits)
# Byte 8: 0x41 ^ 0x46 = 0x7 (3 bits)
# Byte 9: 0x48 ^ 0x54 = 0x1c (3 bits)
# Byte 10: 0x62 ^ 0x48 = 0x2a (3 bits)
# Byte 11: 0x38 ^ 0x6d = 0x55 (4 bits)
# Byte 12: 0x79 ^ 0x76 = 0xf (4 bits)
# Byte 13: 0x62 ^ 0x78 = 0x1a (3 bits)
# Byte 14: 0x5a ^ 0x54 = 0xe (3 bits)
# Byte 15: 0x6a ^ 0x34 = 0x5e (5 bits)
# Byte 16: 0x71 ^ 0x42 = 0x33 (4 bits)
# Byte 17: 0x51 ^ 0x50 = 0x1 (1 bits)
# Byte 18: 0x4d ^ 0x6d = 0x20 (1 bits)
# ...

# %%
import hashlib
print(hashlib.sha256("bitcoin2009-26094".encode()).hexdigest())
# e3feda4138d83f60b66f2c1ebfa5f70a8f684ea8eabf0ebfa7aeadbb2e69eabf
# Out:
# 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097

# %%
TARGET = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")
TEST = binascii.unhexlify("d897680e59e95749d96de29522431bb4329e6c95")
diffs = [bin(TARGET[i] ^ TEST[i]).count('1') for i in range(20)]
print(diffs)  # [6, 4, 7, 0, 0, 6, 0, 6, 2, 3, 6, 5, 5, 5, 4, 4, 4, 4, 6, 0]
print(sum(diffs))  # 77
# Out:
# [4, 4, 6, 0, 0, 4, 0, 5, 2, 2, 6, 5, 4, 5, 2, 3, 3, 3, 6, 0]
# 64

# %%
s1 = binascii.unhexlify("e3feda4138d83f60b66f2c1ebfa5f70a8f684ea8eabf0ebfa7aeadbb2e69eabf")
s2 = binascii.unhexlify("23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097")
xor = bytes(a ^ b for a, b in zip(s1, s2))
print(xor.hex())  # c011a69d19c18a1a428a3c36448d9a4a776b2e48c257c24c531be937d0ef1a28
# Out:
# c011969d19c18a1a428a3c3614a53a2a726bae588257c25c531b09d7d0ef1a28

# %%
import hashlib
from Crypto.Hash import RIPEMD160
import ecdsa
import binascii
import base58

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")
TARGET_ADDRESS = "1FeexV6bAHb8ybZjqQMjJrcCrHGW9sb6uF"

def hamming_distance(b1, b2, label=""):
    print(f"\nHamming Distance Calc ({label}):")
    print(f"b1 (hex): {b1.hex()}")
    print(f"b2 (hex): {b2.hex()}")
    diffs = [bin(b1[i] ^ b2[i]).count('1') for i in range(20)]
    for i, diff in enumerate(diffs):
        xor_val = b1[i] ^ b2[i]
        binary = format(xor_val, '08b')
        print(f"Byte {i}: {hex(b1[i])} ^ {hex(b2[i])} = {hex(xor_val)} ({binary}) -> {diff} bits")
    total = sum(diffs)
    print(f"Total Hamming: {total}")
    return total, diffs

def gen_address_from_priv(priv_key_hex):
    key = ecdsa.SigningKey.from_string(binascii.unhexlify(priv_key_hex), curve=ecdsa.SECP256k1)
    pub_key = key.verifying_key.to_string("uncompressed")
    sha256_hash = hashlib.sha256(pub_key).digest()
    hash160 = RIPEMD160.new(sha256_hash).digest()
    addr_bytes = b'\x00' + hash160
    checksum = hashlib.sha256(hashlib.sha256(addr_bytes).digest()).digest()[:4]
    address = base58.b58encode(addr_bytes + checksum).decode()
    return address, hash160

seed = "bitcoin2009-26094"
print(f"Seed: {seed}")
print(f"Vecna SHA-256(Seed): {hashlib.sha256(seed.encode()).hexdigest()}")

# Your Priv Key
priv_yours = "23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097"
addr_yours, hash160_yours = gen_address_from_priv(priv_yours)
ham_yours_my, diffs_my = hamming_distance(TARGET_HASH160, hash160_yours, "Vecna (Target=Goal)")
ham_yours_jed, diffs_jed = hamming_distance(hash160_yours, TARGET_HASH160, "Jed’s Way")
print(f"\nYour Priv Key Summary:")
print(f"Priv: {priv_yours}")
print(f"Address: {addr_yours}")
print(f"Hash160: {hash160_yours.hex()}")
print(f"Hamming (Vecna): {ham_yours_my}")
print(f"Jed’s XOR Array (Recalc): {diffs_jed} -> Sum: {sum(diffs_jed)}")
print(f"Your XOR Array (Provided): [4, 4, 6, 0, 0, 4, 0, 5, 2, 2, 6, 5, 4, 5, 2, 3, 3, 3, 6, 0] -> Sum: 64")
# Out:
# Seed: bitcoin2009-26094
# Vecna SHA-256(Seed): 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
#
# Hamming Distance Calc (Vecna (Target=Goal)):
# b1 (hex): a0b0d60e5991578ed37cbda2b17d8b2ce23ab295
# b2 (hex): d897680e59e95749d96de29522431bb4329e6c95
# Byte 0: 0xa0 ^ 0xd8 = 0x78 (01111000) -> 4 bits
# Byte 1: 0xb0 ^ 0x97 = 0x27 (00100111) -> 4 bits
# Byte 2: 0xd6 ^ 0x68 = 0xbe (10111110) -> 6 bits
# Byte 3: 0xe ^ 0xe = 0x0 (00000000) -> 0 bits
# Byte 4: 0x59 ^ 0x59 = 0x0 (00000000) -> 0 bits
# Byte 5: 0x91 ^ 0xe9 = 0x78 (01111000) -> 4 bits
# Byte 6: 0x57 ^ 0x57 = 0x0 (00000000) -> 0 bits
# Byte 7: 0x8e ^ 0x49 = 0xc7 (11000111) -> 5 bits
# Byte 8: 0xd3 ^ 0xd9 = 0xa (00001010) -> 2 bits
# Byte 9: 0x7c ^ 0x6d = 0x11 (00010001) -> 2 bits
# Byte 10: 0xbd ^ 0xe2 = 0x5f (01011111) -> 6 bits
# Byte 11: 0xa2 ^ 0x95 = 0x37 (00110111) -> 5 bits
# Byte 12: 0xb1 ^ 0x22 = 0x93 (10010011) -> 4 bits
# Byte 13: 0x7d ^ 0x43 = 0x3e (00111110) -> 5 bits
# ...

# %%
import hashlib
from Crypto.Hash import RIPEMD160
import ecdsa
import binascii
import base58

TARGET_HASH160 = binascii.unhexlify("a0b0d60e5991578ed37cbda2b17d8b2ce23ab295")
TARGET_ADDRESS = "1FeexV6bAHb8ybZjqQMjJrcCrHGW9sb6uF"

def hamming_distance(b1, b2, label=""):
    print(f"\nHamming Distance Calc ({label}):")
    print(f"b1 (hex): {b1.hex()}")
    print(f"b2 (hex): {b2.hex()}")
    diffs = []
    for i in range(20):
        xor_val = b1[i] ^ b2[i]
        binary = format(xor_val, '08b')
        bit_count = binary.count('1')
        diffs.append(bit_count)
        print(f"Byte {i}: {hex(b1[i])} ^ {hex(b2[i])} = {hex(xor_val)} ({binary}) -> {bit_count} bits")
    total = sum(diffs)
    print(f"Total Hamming: {total}")
    return total, diffs

def gen_address_from_priv(priv_key_hex):
    key = ecdsa.SigningKey.from_string(binascii.unhexlify(priv_key_hex), curve=ecdsa.SECP256k1)
    pub_key = key.verifying_key.to_string("uncompressed")
    sha256_hash = hashlib.sha256(pub_key).digest()
    hash160 = RIPEMD160.new(sha256_hash).digest()
    addr_bytes = b'\x00' + hash160
    checksum = hashlib.sha256(hashlib.sha256(addr_bytes).digest()).digest()[:4]
    address = base58.b58encode(addr_bytes + checksum).decode()
    return address, hash160

seed = "bitcoin2009-26094"
print(f"Seed: {seed}")
print(f"Vecna SHA-256(Seed): {hashlib.sha256(seed.encode()).hexdigest()}")

# Your Priv Key
priv_yours = "23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097"
addr_yours, hash160_yours = gen_address_from_priv(priv_yours)
ham_yours_my, diffs_my = hamming_distance(TARGET_HASH160, hash160_yours, "Vecna (Target=Goal)")
ham_yours_jed, diffs_jed = hamming_distance(hash160_yours, TARGET_HASH160, "Jed’s Way")
print(f"\nYour Priv Key Summary:")
print(f"Priv: {priv_yours}")
print(f"Address: {addr_yours}")
print(f"Hash160: {hash160_yours.hex()}")
print(f"Hamming (Vecna): {ham_yours_my}")
print(f"Jed’s XOR Array (Recalc): {diffs_jed} -> Sum: {sum(diffs_jed)}")
print(f"Your XOR Array (Provided): [4, 4, 6, 0, 0, 4, 0, 5, 2, 2, 6, 5, 4, 5, 2, 3, 3, 3, 6, 0] -> Sum: 64")
# Out:
# Seed: bitcoin2009-26094
# Vecna SHA-256(Seed): 23ef4cdc2119b57af4e51028ab00cd20fd03e0f068e8cce3f4b5a46cfe86f097
#
# Hamming Distance Calc (Vecna (Target=Goal)):
# b1 (hex): a0b0d60e5991578ed37cbda2b17d8b2ce23ab295
# b2 (hex): d897680e59e95749d96de29522431bb4329e6c95
# Byte 0: 0xa0 ^ 0xd8 = 0x78 (01111000) -> 4 bits
# Byte 1: 0xb0 ^ 0x97 = 0x27 (00100111) -> 4 bits
# Byte 2: 0xd6 ^ 0x68 = 0xbe (10111110) -> 6 bits
# Byte 3: 0xe ^ 0xe = 0x0 (00000000) -> 0 bits
# Byte 4: 0x59 ^ 0x59 = 0x0 (00000000) -> 0 bits
# Byte 5: 0x91 ^ 0xe9 = 0x78 (01111000) -> 4 bits
# Byte 6: 0x57 ^ 0x57 = 0x0 (00000000) -> 0 bits
# Byte 7: 0x8e ^ 0x49 = 0xc7 (11000111) -> 5 bits
# Byte 8: 0xd3 ^ 0xd9 = 0xa (00001010) -> 2 bits
# Byte 9: 0x7c ^ 0x6d = 0x11 (00010001) -> 2 bits
# Byte 10: 0xbd ^ 0xe2 = 0x5f (01011111) -> 6 bits
# Byte 11: 0xa2 ^ 0x95 = 0x37 (00110111) -> 5 bits
# Byte 12: 0xb1 ^ 0x22 = 0x93 (10010011) -> 4 bits
# Byte 13: 0x7d ^ 0x43 = 0x3e (00111110) -> 5 bits
# ...
